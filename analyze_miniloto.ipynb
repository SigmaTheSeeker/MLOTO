# %% [markdown]
# # miniLOTO解析

# %% [markdown]
# ## n回以上出現する区間

# %%
import analyze_loto as alt

alt.analyze_range_n(1)

# %% [markdown]
# ## 区間集計

# %%
import analyze_loto as alt

alt.analyze_number_count_range(25)
# Out:
# 各数字の出現回数(全区間)
# [1] - [25]
# Count
# [ 1]:(   3) [ 2]:(   8) [ 3]:(   4) [ 4]:(   1) [ 5]:(   1) [ 6]:(   3) [ 7]:(   1) [ 8]:(   4) [ 9]:(   3) [10]:(   3)
# [11]:(   5) [12]:(   4) [13]:(   3) [14]:(   4) [15]:(   2) [16]:(   3) [17]:(   3) [18]:(   5) [19]:(   4) [20]:(   6)
# [21]:(   4) [22]:(   5) [23]:(   3) [24]:(   7) [25]:(   9) [26]:(   6) [27]:(   3) [28]:(   5) [29]:(   3) [30]:(   7)
# [31]:(   3)
# max: 9
# min: 1
# Next: [27, '2000/1/4', 10, 16, 20, 21, 31, 14]
# Rank
# [ 1]:(  17) [ 2]:(   2) [ 3]:(  11) [ 4]:(  29) [ 5]:(  29) [ 6]:(  17) [ 7]:(  29) [ 8]:(  11) [ 9]:(  17) [10]:(  17)
# [11]:(   7) [12]:(  11) [13]:(  17) [14]:(  11) [15]:(  28) [16]:(  17) [17]:(  17) [18]:(   7) [19]:(  11) [20]:(   5)
# [21]:(  11) [22]:(   7) [23]:(  17) [24]:(   3) [25]:(   1) [26]:(   5) [27]:(  17) [28]:(   7) [29]:(  17) [30]:(   3)
# [31]:(  17)
# Next Data
# [10]:(   3) [16]:(   3) [20]:(   6) [21]:(   4) [31]:(   3)
# ...

# %% [markdown]
# ## 偶数奇数の集計

# %%
import analyze_loto as alt

alt.analyze_even_odd()

# %%
temp_tuple = (5, 4, 3, 2, 1)
print(temp_tuple)
print(sorted(temp_tuple))
